# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv("forecasting_data.csv")
df
# Out:
#     Period  Sales
# 0        1   5384
# 1        2   8081
# 2        3  10282
# 3        4   9156
# 4        5   6118
# 5        6   9139
# 6        7  12460
# 7        8  10717
# 8        9   7825
# 9       10   9693
# 10      11  15177
# 11      12  10990

# %%
r = pd.DataFrame(columns = ['Period', 'Sales'])
#r['Period'] = df['Period']+1
#r = r.append({"Period": 14}, ignore_index = True)

for i in range(15):
    r = r.append({'Period': i+1}, ignore_index = True)
r['Period'] = r['Period'].astype(int)
display(r.dtypes)
for i in range(3,15):
    #r = r.append({'Period':i-3, 'Sales': (df.iloc[i-3,1])}, ignore_index = True)
    if (i < 13):
        r.iloc[i,1] = np.round((df.iloc[i-3,1] + df.iloc[i-2,1] + df.iloc[i-1,1])/3,2)
    elif (i == 13):
        r.iloc[i,1] = np.round((df.iloc[i-3,1] + df.iloc[i-2,1])/2,2)
    else:
        r.iloc[i,1] = df.iloc[i-3,1]
    #pass

#for i in range(6):
 #   r['Sales'] = df['Sales'][-3:i]
  #  print(r['Sales'][i])
#r['Sales'] = df['Sales'].rolling(window = 3).mean()
r
# Out:
# Period      int32
# Sales     float64
# dtype: object
#     Period     Sales
# 0        1       NaN
# 1        2       NaN
# 2        3       NaN
# 3        4   7915.67
# 4        5   9173.00
# 5        6   8518.67
# 6        7   8137.67
# 7        8   9239.00
# 8        9  10772.00
# 9       10  10334.00
# 10      11   9411.67
# 11      12  10898.33
# 12      13  11953.33
# 13      14  13083.50
# 14      15  10990.00

# %%
plt.plot(df['Period'], df['Sales'])
plt.plot(r['Period'], r['Sales'])
plt.show()

# %%
es_df = pd.DataFrame(columns = ['Period', 'Sales'])
